# %%
from chunk_scripts import *
from scrape_scripts import *
from dotenv import load_dotenv
import os
import requests
load_dotenv()
# Out:
# True

# %%
from sqlalchemy import create_engine, Column, Integer, String, Text, ForeignKey
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import relationship, sessionmaker

Base = declarative_base()

class Member(Base):
    __tablename__ = 'members'
    
    member_id = Column(Integer, primary_key=True)
    name = Column(String)
    district = Column(Integer)
    session_year = Column(Integer)

class Transcript(Base):
    __tablename__ = 'transcripts'
    
    date = Column(String, primary_key=True)
    text = Column(Text)

class TranscriptSegment(Base):
    __tablename__ = 'transcript_segments'
    
    segment_id = Column(Integer, primary_key=True, autoincrement=True)
    date = Column(String, ForeignKey('transcripts.date'))
    sequence_number = Column(Integer)
    member_id = Column(Integer, ForeignKey('members.member_id'))
    text = Column(Text)

class Activity(Base):
    __tablename__ = 'activity'
    
    activity_id = Column(Integer, primary_key=True, autoincrement=True)
    date = Column(String, ForeignKey('transcripts.date'))
    segment_id = Column(Integer, ForeignKey('transcript_segments.segment_id'))
    member_from = Column(Integer, ForeignKey('members.member_id'))
    member_to = Column(Integer, ForeignKey('members.member_id'))
    interaction = Column(String)
    sentiment = Column(String, default='neutral')
    text_snippet = Column(Text)

# %%
server = os.getenv('DATABASE_URL')

engine = create_engine(server)
Base.metadata.create_all(engine)
Session = sessionmaker(bind=engine)  
session = Session() 

print('connected')
# Out:
# connected

# %% [markdown]
# # Download

# %%
n = 320
links = scrape_links(n)
trans = scrape_transcript_pdfs(links)
# Out:
# Processing 6-17-25 (1 parts)
#   6-17-25...
#     Extracted 659195 chars
#   Total: 659195 chars
#
# Processing 6-16-25 (1 parts)
#   6-16-25...
#     Extracted 560421 chars
#   Total: 560421 chars
#
# Processing 6-13-25 (1 parts)
#   6-13-25...
#     Extracted 128093 chars
#   Total: 128093 chars
#
# Processing 6-12-25 (1 parts)
#   6-12-25-...
#     Extracted 557032 chars
#   Total: 557032 chars
#
# Processing 6-11-25 (1 parts)
#   6-11-25-...
#     Extracted 484818 chars
#   Total: 484818 chars
#
# Processing 6-10-25 (2 parts)
#   6-10-25-Part-1...
#     Extracted 387018 chars
#   6-10-25-Part-2...
#     Extracted 387018 chars
#   Total: 774072 chars
#
# Processing 6-9-25 (2 parts)
#   6-9-25-Part-1...
#     Extracted 220880 chars
#   6-9-25-Part-2...
#     Extracted 220880 chars
#   Total: 441796 chars
#
# Processing 6-6-25 (1 parts)
#   6-6-25-...
#     Extracted 148669 chars
#   Total: 148669 chars
#
# Processing 6-5-25 (1 parts)
#   6-5-25-...
#     Extracted 233645 chars
#   Total: 233645 chars
#
# Processing 6-4-25 (1 parts)
#   6-4-25-Part-3...
#     Extracted 102116 chars
#   Total: 102116 chars
#
# Processing 6-4-25-Part--2 (1 parts)
#   6-4-25-Part--2...
#     Extracted 102116 chars
#   Total: 102116 chars
#
# Processing 6-4-25-Part--1 (1 parts)
#   6-4-25-Part--1...
#     Extracted 102116 chars
#   Total: 102116 chars
#
# Processing 5-29-25 (1 parts)
#   5-29-25-...
#     Extracted 117728 chars
#
# Processing 5-21-24 (1 parts)
#   5-21-24-...
#     Extracted 130740 chars
#   Total: 130740 chars
#
# Processing 5-20-24 (1 parts)
#   5-20-24-...
#     Extracted 66125 chars
#   Total: 66125 chars
#
# Processing 5-16-24 (1 parts)
#   5-16-24-...
#     Extracted 78765 chars
#   Total: 78765 chars
#
# Processing 5-15-24 (1 parts)
#   5-15-24-...
#     Extracted 74173 chars
#   Total: 74173 chars
#
# Processing 5-14-24 (1 parts)
#   5-14-24-...
#     Extracted 86988 chars
#   Total: 86988 chars
#
# Processing 5-13-24 (1 parts)
#   5-13-24-...
#     Extracted 128763 chars
#   Total: 128763 chars
#
# Processing 5-8-24 (1 parts)
#   5-8-24-...
#     Extracted 97360 chars
#   Total: 97360 chars
#
# Processing 5-7-24 (1 parts)
#   5-7-24...
#     Extracted 89185 chars
#   Total: 89185 chars
#
# Processing 5-6-24 (1 parts)
#   5-6-24...
#     Extracted 79314 chars
#   Total: 79314 chars
#
# Processing 4-19-24 (5 parts)
#   4-19-24-Part-1...
#     Extracted 590596 chars
#   4-19-24-Part-2...
#     Extracted 590596 chars
#   4-19-24-Part-3-...
#     Extracted 590596 chars
#   4-19-24-Part-4...
#     Extracted 590596 chars
#   4-19-24-Part-5...
#     Extracted 590596 chars
#   Total: 2953070 chars
#
# Processing 4-18-24 (2 parts)
#   4-18-24-Part-1...
#     Extracted 384896 chars
#   4-18-24-Part-2...
#     Extracted 384896 chars
#   Total: 769828 chars
#
# Processing 4-17-24 (1 parts)
#   4-17-24-...
#     Extracted 52996 chars
#   Total: 52996 chars
#
# Processing 4-16-24 (1 parts)
#   4-16-24...
#     Extracted 40748 chars
#   Total: 40748 chars
#
# Processing 4-15-24 (1 parts)
#   4-15-24-...
#     Extracted 71223 chars
#   Total: 71223 chars
#
# Processing 4-12-24 (1 parts)
#   4-12-24-...
#     Extracted 28815 chars
#   Total: 28815 chars
#
# Processing 4-9-24 (1 parts)
#   4-9-24...
#     Extracted 73870 chars
#   Total: 73870 chars
#
# Processing 4-7-24 (1 parts)
#   4-7-24-...
#     Extracted 11231 chars
#   Total: 11231 chars
#
# Processing 4-4-24 (1 parts)
#   4-4-24-...
#     Extracted 56570 chars
#   Total: 56570 chars
#
# Processing 4-3-24 (1 parts)
#   4-3-24-...
#     Extracted 215538 chars
#   Total: 215538 chars
#
# Processing 4-2-24 (1 parts)
#   4-2-24-...
#     Extracted 119244 chars
#   Total: 119244 chars
#
# Processing 3-28-24 (1 parts)
#   3-28-24-...
#     Extracted 74006 chars
#   Total: 74006 chars
#
# Processing 3-27-24 (1 parts)
#   3-27-24-...
#     Extracted 140535 chars
#   Total: 140535 chars
#
# Processing 3-26-24 (1 parts)
#   3-26-24-...
#     Extracted 139205 chars
#   Total: 139205 chars
#
# Processing 3-25-24 (1 parts)
#   3-25-24-...
#     Extracted 28538 chars
#   Total: 28538 chars
#
# Processing 3-21-24 (1 parts)
#   3-21-24-...
#     Extracted 25686 chars
#   Total: 25686 chars
#
# Processing 3-20-24 (1 parts)
#   3-20-24-...
#     Extracted 69501 chars
#   Total: 69501 chars
#
# Processing 3-19-24 (1 parts)
#   3-19-24-...
#     Extracted 86181 chars
#   Total: 86181 chars
#
# Processing 3-18-24 (1 parts)
#   3-18-24-...
#     Extracted 70354 chars
#   Total: 70354 chars
#
# Processing 3-14-24 (1 parts)
#   3-14-24-...
#     Extracted 198445 chars
#   Total: 198445 chars
#
# Processing 3-13-24 (1 parts)
#   3-13-24...
#     Extracted 144537 chars
#   Total: 144537 chars
#
# Processing 3-12-24 (1 parts)
#   3-12-24-...
#     Extracted 117987 chars
#   Total: 117987 chars
#
# Processing 3-11-24 (1 parts)
#   3-11-24-...
#     Extracted 41745 chars
#   Total: 41745 chars
#
# Processing 3-6-24 (1 parts)
#   3-6-24-...
#     Extracted 79118 chars
#   Total: 79118 chars
#
# Processing 3-5-24 (1 parts)
#   3-5-24-...
#     Extracted 130117 chars
#   Total: 130117 chars
#
# Processing 3-4-24 (1 parts)
#   3-4-24-...
#     Extracted 49786 chars
#   Total: 49786 chars
#
# Processing 2-28-24 (1 parts)
#   2-28-24...
#     Extracted 136649 chars
#   Total: 136649 chars
#
# Processing 2-27-24 (1 parts)
#   2-27-24-...
#     Extracted 62875 chars
#   Total: 62875 chars
#
# Processing 2-26-24 (1 parts)
#   2-26-24-...
#     Extracted 56567 chars
#   Total: 56567 chars
#
# Processing 2-14-24 (1 parts)
#   2-14-24...
#     Extracted 65168 chars
#   Total: 65168 chars
#
# Processing 2-13-24 (1 parts)
#   2-13-24...
#     Extracted 62560 chars
#   Total: 62560 chars
#
# Processing 2-12-24 (1 parts)
#   2-12-24-...
#     Extracted 43000 chars
#   Total: 43000 chars
#
# Processing 2-7-24 (1 parts)
#   2-7-24-...
#     Extracted 50849 chars
#   Total: 50849 chars
#
# Processing 2-6-24 (1 parts)
#   2-6-24-...
#     Extracted 65040 chars
#   Total: 65040 chars
#
# Processing 2-5-24 (1 parts)
#   2-5-24-...
#     Extracted 66299 chars
#   Total: 66299 chars
#
# Processing 1-31-24 (1 parts)
#   1-31-24-...
#     Extracted 41759 chars
#   Total: 41759 chars
#
# Processing 1-30-24 (1 parts)
#   1-30-24-...
#     Extracted 86928 chars
#   Total: 86928 chars
#
# Processing 1-29-24 (1 parts)
#   1-29-24-...
#     Extracted 82525 chars
#   Total: 82525 chars
#
# Processing 1-24-24 (1 parts)
#   1-24-24-...
#     Extracted 65835 chars
#   Total: 65835 chars
#
# Processing 1-23-24 (1 parts)
#   1-23-24...
#     Extracted 52497 chars
#   Total: 52497 chars
#
# Processing 1-22-24 (1 parts)
#   1-22-24...
#     Extracted 60851 chars
#   Total: 60851 chars
#
# Processing 1-17-24 (1 parts)
#   1-17-24-...
#     Extracted 26402 chars
#   Total: 26402 chars
#
# Processing 1-16-24 (1 parts)
#   1-16-24-...
#     Extracted 71933 chars
#   Total: 71933 chars
#
# Processing 1-9-24 (2 parts)
#   1-9-24-Part-1-...
#     Extracted 5299 chars
#   1-9-24-Part-2...
#   Total: 375760 chars
#
# Processing 4-25-23 (1 parts)
#   4-25-23...
#     Extracted 129699 chars
#   Total: 129699 chars
#
# Processing 4-24-23 (1 parts)
#   4-24-23...
#     Extracted 93066 chars
#   Total: 93066 chars
#
# Processing 4-20-23 (1 parts)
#   4-20-23...
#     Extracted 16875 chars
#   Total: 16875 chars
#
# Processing 4-18-23 (1 parts)
#   4-18-23...
#     Extracted 154939 chars
#   Total: 154939 chars
#
# Processing 4-17-23 (1 parts)
#   4-17-23...
#     Extracted 34813 chars
#   Total: 34813 chars
#
# Processing 4-10-23 (1 parts)
#   4-10-23...
#     Extracted 27234 chars
#   Total: 27234 chars
#
# Processing 4-3-23 (1 parts)
#   4-3-23...
#     Extracted 17060 chars
#   Total: 17060 chars
#
# Processing 3-31-23 (1 parts)
#   3-31-23...
#     Extracted 50686 chars
#   Total: 50686 chars
#
# Processing 3-30-23 (1 parts)
#   3-30-23...
#     Extracted 31117 chars
#   Total: 31117 chars
#
# Processing 3-29-23 (1 parts)
#   3-29-23...
#     Extracted 72543 chars
#   Total: 72543 chars
#
# Processing 3-28-23 (1 parts)
#   3-28-23...
#     Extracted 151180 chars
#   Total: 151180 chars
#
# Processing 3-27-23 (1 parts)
#   3-27-23...
#     Extracted 28853 chars
#   Total: 28853 chars
#
# Processing 3-23-23 (1 parts)
#   3-23-23...
#     Extracted 60030 chars
#   Total: 60030 chars
#
# Processing 3-22-23 (1 parts)
#   3-22-23...
#     Extracted 130812 chars
#   Total: 130812 chars
#
# Processing 3-21-23 (1 parts)
#   3-21-23...
#     Extracted 79427 chars
#   Total: 79427 chars
#
# Processing 3-20-23 (1 parts)
#   3-20-23...
#     Extracted 63956 chars
#   Total: 63956 chars
#
# Processing 3-16-23 (1 parts)
#   3-16-23...
#     Extracted 209299 chars
#   Total: 209299 chars
#
# Processing 3-15-23 (1 parts)
#   3-15-23...
#     Extracted 175862 chars
#   Total: 175862 chars
#
# Processing 3-13-23 (1 parts)
#   3-13-23...
#     Extracted 43630 chars
#   Total: 43630 chars
#
# Processing 3-9-23 (1 parts)
#   3-9-23...
#     Extracted 82209 chars
#   Total: 82209 chars
#
# Processing 3-8-23 (1 parts)
#   3-8-23...
#     Extracted 43874 chars
#   Total: 43874 chars
#
# Processing 3-1-23 (1 parts)
#   3-1-23...
#     Extracted 35016 chars
#   Total: 35016 chars
#
# Processing 2-28-23 (1 parts)
#   2-28-23...
#     Extracted 75116 chars
#   Total: 75116 chars
#
# Processing 2-27-23 (1 parts)
#   2-27-23...
#     Extracted 39428 chars
#   Total: 39428 chars
#
# Processing 2-15-23 (1 parts)
#   2-15-23...
#     Extracted 35175 chars
#   Total: 35175 chars
#
# Processing 2-14-23 (1 parts)
#   2-14-23...
#     Extracted 63984 chars
#   Total: 63984 chars
#
# Processing 2-13-23 (1 parts)
#   2-13-23...
#     Extracted 70090 chars
#   Total: 70090 chars
#
# Processing 2-8-23 (1 parts)
#   2-8-23...
#     Extracted 22761 chars
#   Total: 22761 chars
#
#     Extracted 181863 chars
#   Total: 181863 chars
#
# Processing 5-11-22 (1 parts)
#   5-11-22...
#     Extracted 151746 chars
#   Total: 151746 chars
#
# Processing 5-10-22 (1 parts)
#   5-10-22...
#     Extracted 137317 chars
#   Total: 137317 chars
#
# Processing 5-9-22 (1 parts)
#   5-9-22...
#     Extracted 46842 chars
#   Total: 46842 chars
#
# Processing 5-5-22 (1 parts)
#   5-5-22...
#     Extracted 177512 chars
#   Total: 177512 chars
#
# Processing 5-4-22 (1 parts)
#   5-4-22...
#     Extracted 272135 chars
#   Total: 272135 chars
#
# Processing 5-3-22 (1 parts)
#   5-3-22...
#     Extracted 58853 chars
#   Total: 58853 chars
#
# Processing 5-2-22 (1 parts)
#   5-2-22...
#     Extracted 162499 chars
#   Total: 162499 chars
#
# Processing 4-27-22 (1 parts)
#   4-27-22...
#     Extracted 387909 chars
#   Total: 387909 chars
#
# Processing 4-26-22 (1 parts)
#   4-26-22...
#     Extracted 167852 chars
#   Total: 167852 chars
#
# Processing 4-25-22 (1 parts)
#   4-25-22...
#     Extracted 40239 chars
#   Total: 40239 chars
#
# Processing 4-8-22 (3 parts)
#   4-8-22-Part-1...
#     Extracted 691482 chars
#   4-8-22-Part-2...
#     Extracted 691482 chars
#   4-8-22-Part-3...
#     Extracted 691482 chars
#   Total: 2074500 chars
#
# Processing 4-7-22 (2 parts)
#   4-7-22-Part-1...
#     Extracted 278813 chars
#   4-7-22-Part-2...
#     Extracted 278813 chars
#   Total: 557662 chars
#
# Processing 4-6-22 (2 parts)
#   4-6-22-Part-1...
#     Extracted 78494 chars
#   4-6-22-Part-2...
#     Extracted 78494 chars
#   Total: 157024 chars
#
# Processing 4-5-22 (1 parts)
#   4-5-22...
#     Extracted 191532 chars
#   Total: 191532 chars
#
# Processing 4-4-22 (2 parts)
#   4-4-22-Part-1...
#     Extracted 205429 chars
#   4-4-22-Part-2...
#     Extracted 205429 chars
#   Total: 410894 chars
#
# Processing 3-31-22 (1 parts)
#   3-31-22...
#     Extracted 106513 chars
#   Total: 106513 chars
#
# Processing 3-30-22 (1 parts)
#   3-30-22...
#     Extracted 329014 chars
#   Total: 329014 chars
#
# Processing 3-29-22 (1 parts)
#   3-29-22...
#     Extracted 184053 chars
#   Total: 184053 chars
#
# Processing 3-28-22 (1 parts)
#   3-28-22...
#     Extracted 131203 chars
#   Total: 131203 chars
#
# Processing 3-24-22 (1 parts)
#   3-24-22...
#     Extracted 96445 chars
#   Total: 96445 chars
#
# Processing 3-23-22 (1 parts)
#   3-23-22...
#     Extracted 245717 chars
#   Total: 245717 chars
#
# Processing 3-22-22 (1 parts)
#   3-22-22...
#     Extracted 84624 chars
#   Total: 84624 chars
#
# Processing 3-21-22 (1 parts)
#   3-21-22...
#     Extracted 167181 chars
#   Total: 167181 chars
#
# Processing 3-15-22 (1 parts)
#   3-15-22...
#     Extracted 28430 chars
#   Total: 28430 chars
#
# Processing 3-14-22 (1 parts)
#   3-14-22...
#     Extracted 172539 chars
# Processing 1-5-22 (1 parts)
#   1-5-22-...
#     Extracted 1603 chars
#   Total: 1603 chars
#
# Processing 9-1-21 (2 parts)
#   9-1-21-Part-1...
#     Extracted 269904 chars
#   9-1-21-Part-2...
#     Extracted 269904 chars
#   Total: 539844 chars
#
# Processing 6-10-21 (2 parts)
#   6-10-21-Part-1...
#     Extracted 851326 chars
#   6-10-21-Part-2...
#     Extracted 851326 chars
#   Total: 1702688 chars

# %%
file_path = "transcipts.json" # Specify the desired filename
with open(file_path, 'w') as json_file:
    json.dump(trans, json_file, indent=4)

# %%
with open('transcipts.json', 'r') as f:
    transcripts_data = json.load(f)

for date, text in transcripts_data.items():
    transcript = Transcript(date=date, text=text)
    session.add(transcript)

session.commit()

# %% [markdown]
# # member list

# %%
import requests

all_members = []
seen_member_ids = set()

# Query each session year
for year in [2019, 2021, 2023, 2025]:
    url = f"https://legislation.nysenate.gov/api/3/members/{year}/assembly?limit=400&key={key}"
    response = requests.get(url).json()
    
    for member in response['result']['items']:
        member_id = member['memberId']
        
        # Only add if we haven't seen this member_id before
        if member_id not in seen_member_ids:
            all_members.append(member)
            seen_member_ids.add(member_id)

print(f"Total unique members: {len(all_members)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 10
#       8 # Query each session year
#       9 for year in [2019, 2021, 2023, 2025]:
# ---> 10     url = f"https://legislation.nysenate.gov/api/3/members/{year}/assembly?limit=400&key={key}"
#      11     response = requests.get(url).json()
#      13     for member in response['result']['items']:
#
# NameError: name 'key' is not defined

# %%
file_path = "members.json" # Specify the desired filename
with open(file_path, 'w') as json_file:
    json.dump(all_members, json_file, indent=4)

# %%
with open('members.json', 'r') as f:
    members_data = json.load(f)

seen_ids = set()
for member_data in members_data:
    member_id = member_data['memberId']
    if member_id not in seen_ids:
        member = Member(
            member_id=member_id,
            name=member_data['shortName'],
            district=member_data['districtCode'],
            session_year=member_data['sessionYear']
        )
        session.add(member)
        seen_ids.add(member_id)

session.commit()
print(f"Loaded {len(seen_ids)} unique members from {len(members_data)} records")
# Out:
# Loaded 236 unique members from 236 records

# %% [markdown]
# # chunk

# %%
import re
from chunk_scripts import PATTERNS, clean_speech_text, extract_interactions

# Build name lookup dictionary from database
members = session.query(Member).all()
name_to_id = {}
for member in members:
    # Extract surname (last word of name)
    surname = member.name.split()[-1]
    name_to_id[surname] = member.member_id

# Process all transcripts
transcripts = session.query(Transcript).all()
print(f"Processing {len(transcripts)} transcripts...")

segments_created = 0
interactions_created = 0

for transcript in transcripts:
    date = transcript.date
    text = transcript.text
    seq_count = 0
    
    # Store segments for this transcript (needed for extract_interactions)
    transcript_segments = []
    
    # Find all speaker segments in this transcript
    for match in PATTERNS['speaker'].finditer(text):
        title, name, content = match.groups()
        normalized_name = f"{title} {name}"
        surname = normalized_name.split()[-1]
        
        # Look up member_id
        mem_id = name_to_id.get(surname, None)
        cleaned_text = clean_speech_text(content)
        
        # Create TranscriptSegment
        segment = TranscriptSegment(
            date=date,
            sequence_number=seq_count,
            member_id=mem_id,
            text=cleaned_text
        )
        session.add(segment)
        
        # Store for interaction extraction
        transcript_segments.append({
            "name": normalized_name,
            "member_id": mem_id,
            "text": cleaned_text,
            "date": date,
            "sequence": seq_count
        })
        
        seq_count += 1
        segments_created += 1
    
    # Commit segments so they get segment_ids
    session.commit()
    
    # Extract interactions for this transcript
    interactions = extract_interactions(transcript_segments)
    
    # Create Activity records
    for interaction in interactions:
        # Query for the segment_id we just created
        segment = session.query(TranscriptSegment).filter_by(
            date=interaction['date'],
            sequence_number=interaction['sequence']
        ).first()
        
        if segment is None:
            print(f"Warning: No segment found for date={interaction['date']}, sequence={interaction['sequence']}")
            continue
        
        activity = Activity(
            date=interaction['date'],
            segment_id=segment.segment_id,
            member_from=interaction['from_member_id'],
            member_to=interaction['to_member_id'],
            interaction=interaction['interaction_type']
        )
        session.add(activity)
        interactions_created += 1
    
    # Commit activities
    session.commit()
    print(f"Processed {date}: {seq_count} segments, {len(interactions)} interactions")

print(f"\nTotal segments created: {segments_created}")
print(f"Total interactions created: {interactions_created}")
# Out:
# Processing 270 transcripts...
# Processed 6-17-25: 2383 segments, 128 interactions
# Processed 6-16-25: 1682 segments, 97 interactions
# Processed 6-13-25: 273 segments, 2 interactions
# Processed 6-12-25: 1767 segments, 123 interactions
# Processed 6-11-25: 1933 segments, 138 interactions
# Processed 6-10-25: 2754 segments, 168 interactions
# Processed 6-9-25: 1236 segments, 64 interactions
# Processed 6-6-25: 405 segments, 14 interactions
# Processed 6-5-25: 840 segments, 59 interactions
# Processed 6-4-25: 274 segments, 8 interactions
# Processed 6-4-25-Part--2: 274 segments, 8 interactions
# Processed 6-4-25-Part--1: 274 segments, 8 interactions
# Processed 5-29-25: 257 segments, 0 interactions
# Processed 5-28-25: 558 segments, 30 interactions
# Processed 5-27-25: 1400 segments, 86 interactions
# Processed 5-22-25: 79 segments, 6 interactions
# Processed 5-21-25: 189 segments, 1 interactions
# Processed 5-20-25: 445 segments, 20 interactions
# Processed 5-19-25: 101 segments, 0 interactions
# Processed 5-15-25: 440 segments, 23 interactions
# Processed 5-14-25: 527 segments, 26 interactions
# Processed 5-13-25: 652 segments, 22 interactions
# Processed 5-12-25: 103 segments, 0 interactions
# Processed 5-8-25: 5382 segments, 348 interactions
# Processed 5-7-25: 6174 segments, 384 interactions
# Processed 5-6-25: 138 segments, 9 interactions
# Processed 5-5-25: 80 segments, 0 interactions
# Processed 5-1-25: 96 segments, 8 interactions
# Processed 4-30-25: 642 segments, 32 interactions
# Processed 4-29-25: 1017 segments, 56 interactions
# Processed 4-28-25: 48 segments, 1 interactions
# Processed 4-24-25: 88 segments, 6 interactions
# Processed 4-22-25: 117 segments, 4 interactions
# Processed 4-17-25: 110 segments, 4 interactions
# Processed 4-15-25: 110 segments, 0 interactions
# Processed 4-10-25: 104 segments, 10 interactions
# Processed 4-9-25: 178 segments, 4 interactions
# Processed 4-8-25: 89 segments, 5 interactions
# Processed 4-7-25: 226 segments, 12 interactions
# Processed 4-3-25: 180 segments, 10 interactions
# Processed 4-2-25: 219 segments, 11 interactions
# Processed 4-1-25: 232 segments, 8 interactions
# Processed 3-27-25: 326 segments, 12 interactions
# Processed 3-26-25: 664 segments, 38 interactions
# Processed 3-25-25: 191 segments, 13 interactions
# Processed 3-24-25: 111 segments, 4 interactions
# Processed 3-20-25: 147 segments, 9 interactions
# Processed 3-19-25: 636 segments, 38 interactions
# Processed 3-18-25: 55 segments, 2 interactions
# Processed 3-17-25: 30 segments, 0 interactions
# Processed 3-13-25: 510 segments, 31 interactions
# Processed 3-12-25: 696 segments, 33 interactions
# Processed 3-11-25: 221 segments, 12 interactions
# Processed 3-10-25: 50 segments, 0 interactions
# Processed 3-5-25: 315 segments, 20 interactions
# Processed 3-4-25: 83 segments, 3 interactions
# Processed 3-3-25: 280 segments, 16 interactions
# Processed 2-26-25: 133 segments, 10 interactions
# Processed 2-25-25: 248 segments, 10 interactions
# Processed 2-24-25: 610 segments, 35 interactions
# Processed 2-12-25: 164 segments, 6 interactions
# Processed 2-11-25: 287 segments, 14 interactions
# Processed 2-10-25: 37 segments, 0 interactions
# Processed 2-5-25: 49 segments, 0 interactions
# Processed 2-4-25: 65 segments, 0 interactions
# Processed 2-3-25: 60 segments, 0 interactions
# Processed 1-28-25: 71 segments, 1 interactions
# Processed 1-27-25: 102 segments, 4 interactions
# Processed 1-22-25: 642 segments, 30 interactions
# Processed 1-21-25: 51 segments, 0 interactions
# Processed 1-14-25: 34 segments, 0 interactions
# Processed 1-13-25: 240 segments, 18 interactions
# Processed 1-8-25: 13 segments, 0 interactions
# Processed 6-7-24: 7239 segments, 351 interactions
# Processed 6-6-24: 2389 segments, 142 interactions
# Processed 6-5-24: 3570 segments, 210 interactions
# Processed 6-4-24: 2056 segments, 100 interactions
# Processed 6-3-24: 1976 segments, 128 interactions
# Processed 5-30-24: 327 segments, 0 interactions
# Processed 5-29-24: 727 segments, 45 interactions
# Processed 5-28-24: 605 segments, 35 interactions
# Processed 5-23-24: 489 segments, 20 interactions
# Processed 5-22-24: 314 segments, 21 interactions
# Processed 5-21-24: 326 segments, 18 interactions
# Processed 5-20-24: 115 segments, 0 interactions
# Processed 5-16-24: 156 segments, 8 interactions
# Processed 5-15-24: 208 segments, 13 interactions
# Processed 5-14-24: 142 segments, 1 interactions
# Processed 5-13-24: 359 segments, 17 interactions
# Processed 5-8-24: 298 segments, 17 interactions
# Processed 5-7-24: 130 segments, 3 interactions
# Processed 5-6-24: 172 segments, 7 interactions
# Processed 4-19-24: 10065 segments, 500 interactions
# Processed 4-18-24: 2310 segments, 140 interactions
# Processed 4-17-24: 100 segments, 8 interactions
# Processed 4-16-24: 60 segments, 1 interactions
# Processed 4-15-24: 138 segments, 3 interactions
# Processed 4-12-24: 77 segments, 4 interactions
# Processed 4-9-24: 94 segments, 0 interactions
# Processed 4-7-24: 39 segments, 2 interactions
# Processed 4-4-24: 223 segments, 18 interactions
# Processed 4-3-24: 572 segments, 43 interactions
# Processed 4-2-24: 343 segments, 13 interactions
# Processed 3-28-24: 239 segments, 17 interactions
# Processed 3-27-24: 408 segments, 36 interactions
# Processed 3-26-24: 307 segments, 19 interactions
# Processed 3-25-24: 66 segments, 0 interactions
# Processed 3-21-24: 63 segments, 2 interactions
# Processed 3-20-24: 132 segments, 5 interactions
# Processed 3-19-24: 246 segments, 19 interactions
# Processed 3-18-24: 193 segments, 8 interactions
# Processed 3-14-24: 628 segments, 33 interactions
# Processed 3-13-24: 493 segments, 39 interactions
# Processed 3-12-24: 266 segments, 12 interactions
# Processed 3-11-24: 86 segments, 2 interactions
# Processed 3-6-24: 178 segments, 13 interactions
# Processed 3-5-24: 253 segments, 18 interactions
# Processed 3-4-24: 85 segments, 4 interactions
# Processed 2-28-24: 473 segments, 34 interactions
# Processed 2-27-24: 147 segments, 6 interactions
# Processed 2-26-24: 156 segments, 6 interactions
# Processed 2-14-24: 178 segments, 6 interactions
# Processed 2-13-24: 202 segments, 12 interactions
# Processed 2-12-24: 102 segments, 7 interactions
# Processed 2-7-24: 88 segments, 4 interactions
# Processed 2-6-24: 149 segments, 14 interactions
# Processed 2-5-24: 129 segments, 4 interactions
# Processed 1-31-24: 140 segments, 9 interactions
# Processed 1-30-24: 230 segments, 12 interactions
# Processed 1-29-24: 109 segments, 2 interactions
# Processed 1-24-24: 174 segments, 8 interactions
# Processed 1-23-24: 142 segments, 3 interactions
# Processed 1-22-24: 220 segments, 24 interactions
# Processed 1-17-24: 52 segments, 1 interactions
# Processed 1-16-24: 94 segments, 2 interactions
# Processed 1-9-24: 26 segments, 0 interactions
# Processed 1-8-24: 73 segments, 0 interactions
# Processed 6-21-23: 1327 segments, 77 interactions
# Processed 6-20-23: 1874 segments, 110 interactions
# Processed 6-10-23: 890 segments, 51 interactions
# Processed 6-9-23: 2056 segments, 144 interactions
# Processed 6-8-23: 1814 segments, 97 interactions
# Processed 6-7-23: 1455 segments, 98 interactions
# Processed 6-6-23: 786 segments, 45 interactions
# Processed 6-5-23: 404 segments, 13 interactions
# Processed 6-1-23: 684 segments, 32 interactions
# Processed 5-30-23: 220 segments, 0 interactions
# Processed 5-24-23: 274 segments, 7 interactions
# Processed 5-23-23: 165 segments, 6 interactions
# Processed 5-22-23: 209 segments, 8 interactions
# Processed 5-18-23: 386 segments, 24 interactions
# Processed 5-17-23: 435 segments, 14 interactions
# Processed 5-16-23: 482 segments, 35 interactions
# Processed 5-15-23: 131 segments, 2 interactions
# Processed 5-10-23: 237 segments, 11 interactions
# Processed 5-9-23: 383 segments, 30 interactions
# Processed 5-8-23: 135 segments, 4 interactions
# Processed 5-2-23: 4887 segments, 249 interactions
# Processed 5-1-23: 3333 segments, 132 interactions
# Processed 4-26-23: 760 segments, 28 interactions
# Processed 4-25-23: 271 segments, 14 interactions
# Processed 4-24-23: 210 segments, 14 interactions
# Processed 4-20-23: 53 segments, 2 interactions
# Processed 4-18-23: 352 segments, 19 interactions
# Processed 4-17-23: 100 segments, 1 interactions
# Processed 4-10-23: 73 segments, 2 interactions
# Processed 4-3-23: 65 segments, 4 interactions
# Processed 3-31-23: 159 segments, 22 interactions
# Processed 3-30-23: 68 segments, 1 interactions
# Processed 3-29-23: 131 segments, 3 interactions
# Processed 3-28-23: 465 segments, 19 interactions
# Processed 3-27-23: 60 segments, 0 interactions
# Processed 3-23-23: 188 segments, 19 interactions
# Processed 3-22-23: 243 segments, 10 interactions
# Processed 3-21-23: 239 segments, 25 interactions
# Processed 3-20-23: 234 segments, 14 interactions
# Processed 3-16-23: 539 segments, 30 interactions
# Processed 3-15-23: 543 segments, 36 interactions
# Processed 3-13-23: 79 segments, 2 interactions
# Processed 3-9-23: 176 segments, 14 interactions
# Processed 3-8-23: 63 segments, 4 interactions
# Processed 3-1-23: 56 segments, 0 interactions
# Processed 2-28-23: 252 segments, 16 interactions
# Processed 2-27-23: 92 segments, 5 interactions
# Processed 2-15-23: 67 segments, 1 interactions
# Processed 2-14-23: 194 segments, 11 interactions
# Processed 2-13-23: 251 segments, 22 interactions
# Processed 2-8-23: 50 segments, 1 interactions
# Processed 2-7-23: 189 segments, 14 interactions
# Processed 2-6-23: 124 segments, 5 interactions
# Processed 2-1-23: 50 segments, 1 interactions
# Processed 1-31-23: 179 segments, 13 interactions
# Processed 1-30-23: 345 segments, 22 interactions
# Processed 1-25-23: 141 segments, 7 interactions
# Processed 1-24-23: 184 segments, 6 interactions
# Processed 1-23-23: 115 segments, 4 interactions
# Processed 1-18-23: 76 segments, 0 interactions
# Processed 1-17-23: 168 segments, 0 interactions
# Processed 1-10-23: 27 segments, 0 interactions
# Processed 1-9-23: 21 segments, 1 interactions
# Processed 1-4-23: 16 segments, 1 interactions
# Processed 12-22-22: 300 segments, 18 interactions
# Processed 7-1-22: 2326 segments, 140 interactions
# Processed 6-30-22: 24 segments, 0 interactions
# Processed 6-3-22: 2176 segments, 179 interactions
# Processed 6-2-22: 3276 segments, 212 interactions
# Processed 6-1-22: 1582 segments, 94 interactions
# Processed 5-31-22: 635 segments, 33 interactions
# Processed 5-25-22: 163 segments, 9 interactions
# Processed 5-24-22: 317 segments, 8 interactions
# Processed 5-23-22: 303 segments, 8 interactions
# Processed 5-18-22: 647 segments, 59 interactions
# Processed 5-17-22: 1257 segments, 91 interactions
# Processed 5-16-22: 518 segments, 24 interactions
# Processed 5-11-22: 342 segments, 11 interactions
# Processed 5-10-22: 349 segments, 19 interactions
# Processed 5-9-22: 96 segments, 0 interactions
# Processed 5-5-22: 559 segments, 36 interactions
# Processed 5-4-22: 781 segments, 61 interactions
# Processed 5-3-22: 155 segments, 0 interactions
# Processed 5-2-22: 436 segments, 32 interactions
# Processed 4-27-22: 928 segments, 55 interactions
# Processed 4-26-22: 385 segments, 27 interactions
# Processed 4-25-22: 61 segments, 1 interactions
# Processed 4-8-22: 6219 segments, 351 interactions
# Processed 4-7-22: 2034 segments, 74 interactions
# Processed 4-6-22: 356 segments, 24 interactions
# Processed 4-5-22: 465 segments, 38 interactions
# Processed 4-4-22: 1136 segments, 104 interactions
# Processed 3-31-22: 327 segments, 28 interactions
# Processed 3-30-22: 878 segments, 67 interactions
# Processed 3-29-22: 493 segments, 43 interactions
# Processed 3-28-22: 431 segments, 21 interactions
# Processed 3-24-22: 188 segments, 7 interactions
# Processed 3-23-22: 681 segments, 57 interactions
# Processed 3-22-22: 225 segments, 14 interactions
# Processed 3-21-22: 435 segments, 28 interactions
# Processed 3-15-22: 71 segments, 0 interactions
# Processed 3-14-22: 582 segments, 18 interactions
# Processed 3-10-22: 554 segments, 49 interactions
# Processed 3-9-22: 259 segments, 25 interactions
# Processed 3-8-22: 149 segments, 6 interactions
# Processed 3-7-22: 350 segments, 19 interactions
# Processed 3-3-22: 374 segments, 19 interactions
# Processed 3-2-22: 237 segments, 20 interactions
# Processed 3-1-22: 174 segments, 15 interactions
# Processed 2-28-22: 79 segments, 0 interactions
# Processed 2-17-22: 60 segments, 1 interactions
# Processed 2-16-22: 588 segments, 25 interactions
# Processed 2-15-22: 116 segments, 3 interactions
# Processed 2-14-22: 364 segments, 18 interactions
# Processed 2-9-22: 184 segments, 6 interactions
# Processed 2-8-22: 96 segments, 7 interactions
# Processed 2-7-22: 435 segments, 32 interactions
# Processed 2-3-22: 0 segments, 0 interactions
# Processed 2-2-22: 307 segments, 21 interactions
# Processed 2-1-22: 142 segments, 7 interactions
# Processed 1-31-22: 103 segments, 1 interactions
# Processed 1-26-22: 106 segments, 0 interactions
# Processed 1-25-22: 325 segments, 20 interactions
# Processed 1-24-22: 240 segments, 12 interactions
# Processed 1-20-22: 70 segments, 0 interactions
# Processed 1-19-22: 411 segments, 24 interactions
# Processed 1-18-22: 42 segments, 0 interactions
# Processed 1-12-22: 77 segments, 0 interactions
# Processed 1-11-22: 161 segments, 8 interactions
# Processed 1-10-22: 78 segments, 2 interactions
# Processed 1-5-22: 6 segments, 0 interactions
# Processed 9-1-21: 26 segments, 0 interactions
# Processed 6-10-21: 42 segments, 0 interactions
#
# Total segments created: 151870
# Total interactions created: 8484

# %% [markdown]
# # check / test

# %%
# Quick checks after running
print(f"Members: {session.query(Member).count()}")
print(f"Transcripts: {session.query(Transcript).count()}")
print(f"Segments: {session.query(TranscriptSegment).count()}")
print(f"Activities: {session.query(Activity).count()}")

# Spot check  data
print(session.query(Member).limit(5).all())
print(session.query(Activity).limit(5).all())
# Out:
# Members: 236
# Transcripts: 270
# Segments: 151870
# Activities: 8484
# [<__main__.Member object at 0x10feca650>, <__main__.Member object at 0x119e97d90>, <__main__.Member object at 0x119e97250>, <__main__.Member object at 0x119e95550>, <__main__.Member object at 0x119e95010>]
# [<__main__.Activity object at 0x10cc15c50>, <__main__.Activity object at 0x10cc14dd0>, <__main__.Activity object at 0x10cc15ad0>, <__main__.Activity object at 0x10cc168d0>, <__main__.Activity object at 0x119d6f450>]

# %%
import secrets
def generate_api_key():
    
    return secrets.token_urlsafe(32)

keys = {
    "demo_key": generate_api_key(),
    "admin_key": generate_api_key(),
    "user_key": generate_api_key()
}

# Save to file
with open('api_keys.json', 'w') as f:
    json.dump(keys, f, indent=2)

print("API keys generated and saved to api_keys.json\n")
# Out:
# API keys generated and saved to api_keys.json
