# %%
import requests 
import PyPDF2
from io import BytesIO
import re

# %%
from chunk_scripts import *

# %%
test_url = "https://nystateassembly.granicus.com/DocumentViewer.php?file=nystateassembly_3c8d9e7f365d22f77436d2add9220ecc.pdf&view=1"

test = requests.get(test_url)

#converting to bytes to avoid download
pdf = BytesIO(test.content)
file = PyPDF2.PdfReader(pdf)

# %%
full_text = ""
for page in file.pages:
    full_text += page.extract_text() + "\n"

# %% [markdown]
# # Chunking

# %% [markdown]
# ### test

# %%
PATTERNS = {
        #Member speaking 
        'speaker': re.compile(
            r'^(MR\.|MRS\.|MS\.|ACTING SPEAKER|THE CLERK)\s+([A-Z\-\']+):\s+(.+?)(?=^(?:MR\.|MRS\.|MS\.|ACTING SPEAKER|THE CLERK|\(|\[))',
            re.MULTILINE | re.DOTALL
        ),
        
        #Bill information
        'bill_number': re.compile(r'(?:Assembly|Senate) No\.\s+([AS]\d{5}(?:-[A-Z])?)', re.IGNORECASE),
        'calendar_number': re.compile(r'Calendar No\.\s+(\d+)', re.IGNORECASE),
        'rules_report': re.compile(r'Rules Report No\.\s+(\d+)', re.IGNORECASE),
        
        #Session metadata
        'session_date': re.compile(r'^[\d]*([A-Z]+,\s+[A-Z]+\s+\d{1,2},\s+\d{4})', re.MULTILINE),
        'page_number': re.compile(r'NYS ASSEMBLY\s+JUNE \d{1,2}, \d{4}\s*\n\s*(\d+)', re.MULTILINE),
        
        #Interaction patterns
        'yield_question': re.compile(
            r'Will\s+(?:the\s+sponsor|(?:Mr\.|Mrs\.|Ms\.)\s+([A-Z\-\']+))\s+yield',
            re.IGNORECASE
        ),
        'direct_address': re.compile(
            r'((?:Mr\.|Mrs\.|Ms\.)\s+[A-Z\-\']+)',
            re.IGNORECASE
        ),
        'thank_response': re.compile(
            r'Thank you,?\s+((?:Mr\.|Mrs\.|Ms\.)\s+[A-Z\-\']+)',
            re.IGNORECASE
        ),
        
        #Questions (for counting)
        'question_mark': re.compile(r'\?'),
        
        #Procedural
        'motion': re.compile(r'\bmove\b', re.IGNORECASE),
        'call_committee': re.compile(r'call.*?committee', re.IGNORECASE),
    }

# %%
date_match = PATTERNS['session_date'].search(full_text)

if date_match:
    session_date = date_match.group(1)
    
session_date
# Out:
# 'WEDNESDAY, JUNE 11, 2025'

# %%
all_member_names = []
speaker_text = []

for match in PATTERNS['speaker'].finditer(full_text):
    title, name, content = match.groups()
    
    normalized_name = f"{title} {name}"
    speaker_text.append({normalized_name : clean_speech_text(content)})
    
    
    if not title.startswith("THE CLERK"):
        all_member_names.append(normalized_name)

# %%
speaker_text[0]
# Out:
# {'ACTING SPEAKER HUNTER': 'The House will \ncome to order. \nGood morning, colleagues. \nIn the absence of clergy, let us pause for a moment of \nsilence.'}

# %%
check = extract_interactions(speaker_text, all_member_names)

check
# Out:
# [{'from_member': 'MRS. PEOPLES-STOKES',
#   'to_member': 'MS. ROZIC',
#   'interaction_type': 'address',
#   'text_snippet': 'Ms. Rozic',
#   'position': 3},
#  {'from_member': 'MR. JENSEN',
#   'to_member': 'MS. ROZIC',
#   'interaction_type': 'address',
#   'text_snippet': 'Ms. Rozic',
#   'position': 31},
#  {'from_member': 'MR. JENSEN',
#   'to_member': 'MS. ROZIC',
#   'interaction_type': 'address',
#   'text_snippet': 'MS. ROZIC',
#   'position': 57},
#  {'from_member': 'MR. JENSEN',
#   'to_member': 'MS. ROZIC',
#   'interaction_type': 'address',
#   'text_snippet': 'MS. ROZIC',
#   'position': 66},
#  {'from_member': 'MS. ROZIC',
#   'to_member': 'MR. JENSEN',
#   'interaction_type': 'address',
#   'text_snippet': 'MR. JENSEN',
#   'position': 70},
#  {'from_member': 'MR. ANGELINO',
#   'to_member': 'MS. WOERNER',
#   'interaction_type': 'address',
#   'text_snippet': 'MS. WOERNER',
#   'position': 113},
#  {'from_member': 'MR. ANGELINO',
#   'to_member': 'MS. WOERNER',
#   'interaction_type': 'address',
#   'text_snippet': 'MS. WOERNER',
#   'position': 126},
#  {'from_member': 'MS. WOERNER',
#   'to_member': 'MR. ANGELINO',
#   'interaction_type': 'address',
#   'text_snippet': 'MR. ANGELINO',
#   'position': 138},
#  {'from_member': 'MR. ANGELINO',
#   'to_member': 'MS. WOERNER',
#   'interaction_type': 'address',
#   'text_snippet': 'MS. WOERNER',
#   'position': 150},
#  {'from_member': 'MR. REILLY',
#   'to_member': 'MR. ANGELINO',
#   'interaction_type': 'question',
#   'text_snippet': 'Will \nthe sponsor yield',
#   'position': 157},
#  {'from_member': 'MR. REILLY',
#   'to_member': 'MS. WOERNER',
#   'interaction_type': 'address',
#   'text_snippet': 'Ms. Woerner',
#   'position': 161},
#  {'from_member': 'MR. FALL',
#   'to_member': 'MR. GANDOLFO',
#   'interaction_type': 'address',
#   'text_snippet': 'MR. GANDOLFO',
#   'position': 200},
#  {'from_member': 'MR. PALMESANO',
#   'to_member': 'MR. GANDOLFO',
#   'interaction_type': 'question',
#   'text_snippet': 'Will the \nsponsor yield',
#   'position': 222},
#  {'from_member': 'MR. PALMESANO',
#   'to_member': 'MR. FALL',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. Fall',
#   'position': 226},
#  {'from_member': 'MR. FALL',
#   'to_member': 'MR. PALMESANO',
#   'interaction_type': 'address',
#   'text_snippet': 'MR. PALMESANO',
#   'position': 227},
#  {'from_member': 'MR. FALL',
#   'to_member': 'MR. PALMESANO',
#   'interaction_type': 'address',
#   'text_snippet': 'MR. PALMESANO',
#   'position': 248},
#  {'from_member': 'MR. PALMESANO',
#   'to_member': 'MR. FALL',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. Fall',
#   'position': 258},
#  {'from_member': 'MR. RA',
#   'to_member': 'MR. SLATER',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. \nSlater',
#   'position': 331},
#  {'from_member': 'MRS. PEOPLES-STOKES',
#   'to_member': 'MR. SMULLEN',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. \nSmullen',
#   'position': 346},
#  {'from_member': 'MRS. PEOPLES-STOKES',
#   'to_member': 'MR. CARROLL',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. Carroll',
#   'position': 352},
#  {'from_member': 'MS. WALSH',
#   'to_member': 'MRS. PEOPLES-STOKES',
#   'interaction_type': 'question',
#   'text_snippet': 'Will the \nsponsor yield',
#   'position': 356},
#  {'from_member': 'MRS. BAILEY',
#   'to_member': 'MR. STECK',
#   'interaction_type': 'question',
#   'text_snippet': 'Will the \nsponsor yield',
#   'position': 374},
#  {'from_member': 'MR. CARROLL',
#   'to_member': 'MRS. BAILEY',
#   'interaction_type': 'address',
#   'text_snippet': 'MRS. BAILEY',
#   'position': 376},
#  {'from_member': 'MS. GIGLIO',
#   'to_member': 'MS. WALSH',
#   'interaction_type': 'question',
#   'text_snippet': 'Will the \nsponsor yield',
#   'position': 400},
#  {'from_member': 'MR. MIKULIN',
#   'to_member': 'MS. ROSENTHAL',
#   'interaction_type': 'question',
#   'text_snippet': 'Will the sponsor yield',
#   'position': 418},
#  {'from_member': 'MR. BOLOGNA',
#   'to_member': 'MS. ROSENTHAL',
#   'interaction_type': 'address',
#   'text_snippet': 'Ms. \nRosenthal',
#   'position': 461},
#  {'from_member': 'MR. BOLOGNA',
#   'to_member': 'MS. ROSENTHAL',
#   'interaction_type': 'address',
#   'text_snippet': 'Ms. Rosenthal',
#   'position': 473},
#  {'from_member': 'MR. SEMPOLINSKI',
#   'to_member': 'MR. JACOBSON',
#   'interaction_type': 'question',
#   'text_snippet': 'Will the sponsor yield',
#   'position': 485},
#  {'from_member': 'MR. SEMPOLINSKI',
#   'to_member': 'MR. JACOBSON',
#   'interaction_type': 'address',
#   'text_snippet': 'MR. JACOBSON',
#   'position': 496},
#  {'from_member': 'MR. SEMPOLINSKI',
#   'to_member': 'MR. JACOBSON',
#   'interaction_type': 'address',
#   'text_snippet': 'MR. JACOBSON',
#   'position': 499},
#  {'from_member': 'MR. JACOBSON',
#   'to_member': 'MR. SEMPOLINSKI',
#   'interaction_type': 'address',
#   'text_snippet': 'MR. SEMPOLINSKI',
#   'position': 533},
#  {'from_member': 'MR. RA',
#   'to_member': 'MR. SEMPOLINSKI',
#   'interaction_type': 'question',
#   'text_snippet': 'Will the \nsponsor yield',
#   'position': 557},
#  {'from_member': 'MR. RA',
#   'to_member': 'MR. JACOBSON',
#   'interaction_type': 'address',
#   'text_snippet': 'MR. JACOBSON',
#   'position': 561},
#  {'from_member': 'MR. RA',
#   'to_member': 'MR. JACOBSON',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. Jacobson',
#   'position': 568},
#  {'from_member': 'MR. MORINELLO',
#   'to_member': 'MR. RA',
#   'interaction_type': 'question',
#   'text_snippet': 'Will the sponsor \nyield',
#   'position': 572},
#  {'from_member': 'MR. JACOBSON',
#   'to_member': 'MR. MORINELLO',
#   'interaction_type': 'address',
#   'text_snippet': 'MR. MORINELLO',
#   'position': 591},
#  {'from_member': 'MR. PIROZZOLO',
#   'to_member': 'MR. JACOBSON',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. Jacobson',
#   'position': 608},
#  {'from_member': 'MR. JACOBSON',
#   'to_member': 'MR. PIROZZOLO',
#   'interaction_type': 'address',
#   'text_snippet': 'MR. PIROZZOLO',
#   'position': 617},
#  {'from_member': 'MR. JACOBSON',
#   'to_member': 'MR. PIROZZOLO',
#   'interaction_type': 'address',
#   'text_snippet': 'MR. PIROZZOLO',
#   'position': 630},
#  {'from_member': 'MR. PIROZZOLO',
#   'to_member': 'MR. LAVINE',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. Lavine',
#   'position': 634},
#  {'from_member': 'MR. LAVINE',
#   'to_member': 'MR. PIROZZOLO',
#   'interaction_type': 'question',
#   'text_snippet': 'Will the sponsor yield',
#   'position': 635},
#  {'from_member': 'MR. LAVINE',
#   'to_member': 'MR. JACOBSON',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. Jacobson',
#   'position': 639},
#  {'from_member': 'MR. DURSO',
#   'to_member': 'MR. JACOBSON',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. Jacobson',
#   'position': 648},
#  {'from_member': 'MR. JACOBSON',
#   'to_member': 'MR. DURSO',
#   'interaction_type': 'address',
#   'text_snippet': 'MR. DURSO',
#   'position': 657},
#  {'from_member': 'MR. DURSO',
#   'to_member': 'MR. JACOBSON',
#   'interaction_type': 'address',
#   'text_snippet': 'MR. JACOBSON',
#   'position': 671},
#  {'from_member': 'MR. DURSO',
#   'to_member': 'MR. JACOBSON',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. Jacobson',
#   'position': 702},
#  {'from_member': 'MR. DURSO',
#   'to_member': 'MR. JACOBSON',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. Jacobson',
#   'position': 708},
#  {'from_member': 'MS. LUNSFORD',
#   'to_member': 'MR. JACOBSON',
#   'interaction_type': 'address',
#   'text_snippet': 'MR. JACOBSON',
#   'position': 723},
#  {'from_member': 'MR. JACOBSON',
#   'to_member': 'MS. LUNSFORD',
#   'interaction_type': 'address',
#   'text_snippet': 'MS. LUNSFORD',
#   'position': 735},
#  {'from_member': 'MR. TAGUE',
#   'to_member': 'MR. JACOBSON',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. Jacobson',
#   'position': 759},
#  {'from_member': 'MR. TAGUE',
#   'to_member': 'MS. LUNSFORD',
#   'interaction_type': 'address',
#   'text_snippet': 'Ms. Lunsford',
#   'position': 765},
#  {'from_member': 'MR. TAGUE',
#   'to_member': 'MR. JACOBSON',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. Jacobson',
#   'position': 771},
#  {'from_member': 'MR. BOLOGNA',
#   'to_member': 'MR. TAGUE',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. Tague',
#   'position': 782},
#  {'from_member': 'MR. DURSO',
#   'to_member': 'MR. STECK',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. Steck',
#   'position': 808},
#  {'from_member': 'MR. DURSO',
#   'to_member': 'MR. STECK',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. Steck',
#   'position': 812},
#  {'from_member': 'MR. DURSO',
#   'to_member': 'MR. STECK',
#   'interaction_type': 'address',
#   'text_snippet': 'MR. STECK',
#   'position': 831},
#  {'from_member': 'MR. DURSO',
#   'to_member': 'MR. STECK',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. Steck',
#   'position': 836},
#  {'from_member': 'MS. WALSH',
#   'to_member': 'MR. STECK',
#   'interaction_type': 'question',
#   'text_snippet': 'Will the \nsponsor yield',
#   'position': 839},
#  {'from_member': 'MR. RA',
#   'to_member': 'MS. TAPIA',
#   'interaction_type': 'question',
#   'text_snippet': 'Will the \nsponsor yield',
#   'position': 862},
#  {'from_member': 'MR. RA',
#   'to_member': 'MS. TAPIA',
#   'interaction_type': 'address',
#   'text_snippet': 'MS. TAPIA',
#   'position': 884},
#  {'from_member': 'MRS. PEOPLES-STOKES',
#   'to_member': 'MR. HEVESI',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. Hevesi',
#   'position': 902},
#  {'from_member': 'MR. HEVESI',
#   'to_member': 'MS. WALSH',
#   'interaction_type': 'address',
#   'text_snippet': 'Ms. Walsh',
#   'position': 905},
#  {'from_member': 'MS. WALSH',
#   'to_member': 'MR. HEVESI',
#   'interaction_type': 'question',
#   'text_snippet': 'will the sponsor \nyield',
#   'position': 907},
#  {'from_member': 'MR. HEVESI',
#   'to_member': 'MS. WALSH',
#   'interaction_type': 'address',
#   'text_snippet': 'MS. WALSH',
#   'position': 927},
#  {'from_member': 'MR. HEVESI',
#   'to_member': 'MS. WALSH',
#   'interaction_type': 'address',
#   'text_snippet': 'Ms. Walsh',
#   'position': 952},
#  {'from_member': 'MS. WALSH',
#   'to_member': 'MR. HEVESI',
#   'interaction_type': 'address',
#   'text_snippet': 'MR. HEVESI',
#   'position': 957},
#  {'from_member': 'MS. WALSH',
#   'to_member': 'MR. HEVESI',
#   'interaction_type': 'address',
#   'text_snippet': 'MR. HEVESI',
#   'position': 990},
#  {'from_member': 'MR. HEVESI',
#   'to_member': 'MS. WALSH',
#   'interaction_type': 'address',
#   'text_snippet': 'MS. WALSH',
#   'position': 998},
#  {'from_member': 'MS. WALSH',
#   'to_member': 'MR. HEVESI',
#   'interaction_type': 'address',
#   'text_snippet': 'MR. HEVESI',
#   'position': 1008},
#  {'from_member': 'MR. HEVESI',
#   'to_member': 'MS. WALSH',
#   'interaction_type': 'address',
#   'text_snippet': 'MS. WALSH',
#   'position': 1018},
#  {'from_member': 'MS. WALSH',
#   'to_member': 'MR. HEVESI',
#   'interaction_type': 'address',
#   'text_snippet': 'MR. HEVESI',
#   'position': 1064},
#  {'from_member': 'MR. HEVESI',
#   'to_member': 'MS. WALSH',
#   'interaction_type': 'address',
#   'text_snippet': 'Ms. Walsh',
#   'position': 1080},
#  {'from_member': 'MR. HEVESI',
#   'to_member': 'MR. CHANG',
#   'interaction_type': 'address',
#   'text_snippet': 'MR. CHANG',
#   'position': 1089},
#  {'from_member': 'MR. HEVESI',
#   'to_member': 'MR. CHANG',
#   'interaction_type': 'address',
#   'text_snippet': 'MR. CHANG',
#   'position': 1094},
#  {'from_member': 'MR. MANKTELOW',
#   'to_member': 'MR. HEVESI',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. Hevesi',
#   'position': 1118},
#  {'from_member': 'MR. HEVESI',
#   'to_member': 'MR. MANKTELOW',
#   'interaction_type': 'address',
#   'text_snippet': 'MR. MANKTELOW',
#   'position': 1133},
#  {'from_member': 'MR. HEVESI',
#   'to_member': 'MR. MANKTELOW',
#   'interaction_type': 'address',
#   'text_snippet': 'MR. MANKTELOW',
#   'position': 1152},
#  {'from_member': 'MR. MANKTELOW',
#   'to_member': 'MR. HEVESI',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. Hevesi',
#   'position': 1158},
#  {'from_member': 'MR. HEVESI',
#   'to_member': 'MS. WALSH',
#   'interaction_type': 'address',
#   'text_snippet': 'Ms. Walsh',
#   'position': 1173},
#  {'from_member': 'MR. BURROUGHS',
#   'to_member': 'MRS. PEOPLES-STOKES',
#   'interaction_type': 'question',
#   'text_snippet': 'will the sponsor \nyield',
#   'position': 1179},
#  {'from_member': 'MR. ANGELINO',
#   'to_member': 'MR. ANDERSON',
#   'interaction_type': 'question',
#   'text_snippet': 'Will the sponsor yield',
#   'position': 1203},
#  {'from_member': 'MR. ANDERSON',
#   'to_member': 'MR. ANGELINO',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. Angelino',
#   'position': 1205},
#  {'from_member': 'MR. ANDERSON',
#   'to_member': 'MR. MORINELLO',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. Morinello',
#   'position': 1218},
#  {'from_member': 'MR. ANGELINO',
#   'to_member': 'MR. ANDERSON',
#   'interaction_type': 'address',
#   'text_snippet': 'MR. ANDERSON',
#   'position': 1257},
#  {'from_member': 'MR. ANGELINO',
#   'to_member': 'MR. ANDERSON',
#   'interaction_type': 'address',
#   'text_snippet': 'MR. ANDERSON',
#   'position': 1276},
#  {'from_member': 'MR. ANDERSON',
#   'to_member': 'MR. ANGELINO',
#   'interaction_type': 'address',
#   'text_snippet': 'MR. ANGELINO',
#   'position': 1284},
#  {'from_member': 'MR. GALLAHAN',
#   'to_member': 'MR. ANGELINO',
#   'interaction_type': 'question',
#   'text_snippet': 'Will the sponsor yield',
#   'position': 1328},
#  {'from_member': 'MR. ANDERSON',
#   'to_member': 'MR. GALLAHAN',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. \nGallahan',
#   'position': 1330},
#  {'from_member': 'MR. GALLAHAN',
#   'to_member': 'MR. ANDERSON',
#   'interaction_type': 'address',
#   'text_snippet': 'MR. ANDERSON',
#   'position': 1336},
#  {'from_member': 'MR. ANDERSON',
#   'to_member': 'MR. GALLAHAN',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. Gallahan',
#   'position': 1344},
#  {'from_member': 'MR. ANDERSON',
#   'to_member': 'MR. GALLAHAN',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. Gallahan',
#   'position': 1346},
#  {'from_member': 'MR. ANDERSON',
#   'to_member': 'MR. GALLAHAN',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. \nGallahan',
#   'position': 1352},
#  {'from_member': 'MR. ANDERSON',
#   'to_member': 'MR. GALLAHAN',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. \nGallahan',
#   'position': 1362},
#  {'from_member': 'MR. MOLITOR',
#   'to_member': 'MR. GALLAHAN',
#   'interaction_type': 'question',
#   'text_snippet': 'Will \nthe sponsor yield',
#   'position': 1367},
#  {'from_member': 'MR. ANDERSON',
#   'to_member': 'MR. MOLITOR',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. Molitor',
#   'position': 1369},
#  {'from_member': 'MR. MOLITOR',
#   'to_member': 'MR. ANDERSON',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. Anderson',
#   'position': 1371},
#  {'from_member': 'MR. ANDERSON',
#   'to_member': 'MR. MOLITOR',
#   'interaction_type': 'address',
#   'text_snippet': 'MR. MOLITOR',
#   'position': 1386},
#  {'from_member': 'MR. ANDERSON',
#   'to_member': 'MR. MOLITOR',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. Molitor',
#   'position': 1393},
#  {'from_member': 'MR. ANDERSON',
#   'to_member': 'MR. MOLITOR',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. Molitor',
#   'position': 1395},
#  {'from_member': 'MR. ANDERSON',
#   'to_member': 'MR. MOLITOR',
#   'interaction_type': 'address',
#   'text_snippet': 'MR. MOLITOR',
#   'position': 1399},
#  {'from_member': 'MR. MOLITOR',
#   'to_member': 'MR. ANDERSON',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. Anderson',
#   'position': 1415},
#  {'from_member': 'MR. ANDERSON',
#   'to_member': 'MRS. BAILEY',
#   'interaction_type': 'address',
#   'text_snippet': 'MRS. BAILEY',
#   'position': 1440},
#  {'from_member': 'MR. REILLY',
#   'to_member': 'MR. ANDERSON',
#   'interaction_type': 'question',
#   'text_snippet': 'Will \nthe sponsor yield',
#   'position': 1449},
#  {'from_member': 'MR. ANDERSON',
#   'to_member': 'MR. REILLY',
#   'interaction_type': 'address',
#   'text_snippet': 'MR. REILLY',
#   'position': 1464},
#  {'from_member': 'MR. ANDERSON',
#   'to_member': 'MR. REILLY',
#   'interaction_type': 'address',
#   'text_snippet': 'MR. REILLY',
#   'position': 1475},
#  {'from_member': 'MR. REILLY',
#   'to_member': 'MR. ANDERSON',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. \nAnderson',
#   'position': 1483},
#  {'from_member': 'MR. ANDERSON',
#   'to_member': 'MR. REILLY',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. Reilly',
#   'position': 1484},
#  {'from_member': 'MR. LEMONDES',
#   'to_member': 'MR. ANDERSON',
#   'interaction_type': 'question',
#   'text_snippet': 'Will the sponsor yield',
#   'position': 1486},
#  {'from_member': 'MR. ANDERSON',
#   'to_member': 'MR. LEMONDES',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. Lemondes',
#   'position': 1488},
#  {'from_member': 'MR. LEMONDES',
#   'to_member': 'MR. ANDERSON',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. Anderson',
#   'position': 1490},
#  {'from_member': 'MR. ANDERSON',
#   'to_member': 'MR. LEMONDES',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. Lemondes',
#   'position': 1493},
#  {'from_member': 'MR. ANDERSON',
#   'to_member': 'MR. LEMONDES',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. Lemondes',
#   'position': 1501},
#  {'from_member': 'MR. ANDERSON',
#   'to_member': 'MR. LEMONDES',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. Lemondes',
#   'position': 1503},
#  {'from_member': 'MR. ANDERSON',
#   'to_member': 'MR. LEMONDES',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. \nLemondes',
#   'position': 1505},
#  {'from_member': 'MR. LEMONDES',
#   'to_member': 'MR. ANDERSON',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. Anderson',
#   'position': 1512},
#  {'from_member': 'MR. MANKTELOW',
#   'to_member': 'MR. LEMONDES',
#   'interaction_type': 'question',
#   'text_snippet': 'Will the sponsor \nyield',
#   'position': 1515},
#  {'from_member': 'MR. MANKTELOW',
#   'to_member': 'MR. ANDERSON',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. Anderson',
#   'position': 1517},
#  {'from_member': 'MR. MANKTELOW',
#   'to_member': 'MR. ANDERSON',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. Anderson',
#   'position': 1519},
#  {'from_member': 'MS. WALSH',
#   'to_member': 'MS. LEE',
#   'interaction_type': 'question',
#   'text_snippet': 'Will the \nsponsor yield',
#   'position': 1562},
#  {'from_member': 'MR. CHANG',
#   'to_member': 'MS. WALSH',
#   'interaction_type': 'question',
#   'text_snippet': 'Will the sponsor \nyield',
#   'position': 1580},
#  {'from_member': 'MR. CHANG',
#   'to_member': 'MS. LEE',
#   'interaction_type': 'address',
#   'text_snippet': 'Ms. Lee',
#   'position': 1583},
#  {'from_member': 'MR. CHANG',
#   'to_member': 'MS. LEE',
#   'interaction_type': 'address',
#   'text_snippet': 'Ms. Lee',
#   'position': 1585},
#  {'from_member': 'MS. PAULIN',
#   'to_member': 'MS. WALSH',
#   'interaction_type': 'address',
#   'text_snippet': 'MS. WALSH',
#   'position': 1617},
#  {'from_member': 'MS. WALSH',
#   'to_member': 'MS. PAULIN',
#   'interaction_type': 'address',
#   'text_snippet': 'MS. PAULIN',
#   'position': 1639},
#  {'from_member': 'MR. MOLITOR',
#   'to_member': 'MS. WALSH',
#   'interaction_type': 'question',
#   'text_snippet': 'Will \nthe sponsor yield',
#   'position': 1660},
#  {'from_member': 'MR. MOLITOR',
#   'to_member': 'MS. PAULIN',
#   'interaction_type': 'address',
#   'text_snippet': 'MS. PAULIN',
#   'position': 1684},
#  {'from_member': 'MS. PAULIN',
#   'to_member': 'MR. MOLITOR',
#   'interaction_type': 'address',
#   'text_snippet': 'MR. MOLITOR',
#   'position': 1692},
#  {'from_member': 'MR. MOLITOR',
#   'to_member': 'MS. PAULIN',
#   'interaction_type': 'address',
#   'text_snippet': 'MS. PAULIN',
#   'position': 1698},
#  {'from_member': 'MS. GLICK',
#   'to_member': 'MR. SIMPSON',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. Simpson',
#   'position': 1721},
#  {'from_member': 'MS. GLICK',
#   'to_member': 'MR. ANGELINO',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. Angelino',
#   'position': 1730},
#  {'from_member': 'MS. GLICK',
#   'to_member': 'MR. SIMPSON',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. Simpson',
#   'position': 1750},
#  {'from_member': 'MR. BOLOGNA',
#   'to_member': 'MR. EPSTEIN',
#   'interaction_type': 'address',
#   'text_snippet': 'Mr. Epstein',
#   'position': 1765},
#  {'from_member': 'MR. EPSTEIN',
#   'to_member': 'MR. BOLOGNA',
#   'interaction_type': 'address',
#   'text_snippet': 'MR. BOLOGNA',
#   'position': 1768},
#  {'from_member': 'MS. WALSH',
#   'to_member': 'MS. SEPTIMO',
#   'interaction_type': 'question',
#   'text_snippet': 'Will the \nsponsor yield',
#   'position': 1780},
#  {'from_member': 'MS. SEPTIMO',
#   'to_member': 'MS. WALSH',
#   'interaction_type': 'address',
#   'text_snippet': 'MS. WALSH',
#   'position': 1799},
#  {'from_member': 'MS. SEPTIMO',
#   'to_member': 'MS. WALSH',
#   'interaction_type': 'address',
#   'text_snippet': 'MS. WALSH',
#   'position': 1824},
#  {'from_member': 'MS. SEPTIMO',
#   'to_member': 'MS. WALSH',
#   'interaction_type': 'address',
#   'text_snippet': 'MS. WALSH',
#   'position': 1833},
#  {'from_member': 'MR. MOLITOR',
#   'to_member': 'MS. WALSH',
#   'interaction_type': 'question',
#   'text_snippet': 'Will \nthe sponsor yield',
#   'position': 1844},
#  {'from_member': 'MR. MOLITOR',
#   'to_member': 'MS. SEPTIMO',
#   'interaction_type': 'address',
#   'text_snippet': 'MS. SEPTIMO',
#   'position': 1900}]

# %% [markdown]
# ### scripts

# %%
PATTERNS = {
        #Member speaking 
        'speaker': re.compile(
            r'^(MR\.|MRS\.|MS\.|ACTING SPEAKER|THE CLERK)\s+([A-Z\-\']+):\s+(.+?)(?=^(?:MR\.|MRS\.|MS\.|ACTING SPEAKER|THE CLERK|\(|\[))',
            re.MULTILINE | re.DOTALL
        ),
        
        #Bill information
        'bill_number': re.compile(r'(?:Assembly|Senate) No\.\s+([AS]\d{5}(?:-[A-Z])?)', re.IGNORECASE),
        'calendar_number': re.compile(r'Calendar No\.\s+(\d+)', re.IGNORECASE),
        'rules_report': re.compile(r'Rules Report No\.\s+(\d+)', re.IGNORECASE),
        
        #Session metadata
        'session_date': re.compile(r'^[\d]*([A-Z]+,\s+[A-Z]+\s+\d{1,2},\s+\d{4})', re.MULTILINE),
        'page_number': re.compile(r'NYS ASSEMBLY\s+JUNE \d{1,2}, \d{4}\s*\n\s*(\d+)', re.MULTILINE),
        
        #Interaction patterns
        'yield_question': re.compile(
            r'Will\s+(?:the\s+sponsor|(?:Mr\.|Mrs\.|Ms\.)\s+([A-Z\-\']+))\s+yield',
            re.IGNORECASE
        ),
        'direct_address': re.compile(
            r'((?:Mr\.|Mrs\.|Ms\.)\s+[A-Z\-\']+)',
            re.IGNORECASE
        ),
        'thank_response': re.compile(
            r'Thank you,?\s+((?:Mr\.|Mrs\.|Ms\.)\s+[A-Z\-\']+)',
            re.IGNORECASE
        ),
        
        #Questions (for counting)
        'question_mark': re.compile(r'\?'),
        
        #Procedural
        'motion': re.compile(r'\bmove\b', re.IGNORECASE),
        'call_committee': re.compile(r'call.*?committee', re.IGNORECASE),
    }


def clean_speech_text(text: str) -> str:
    """
    Clean up speech text by removing date artifacts and other noise.
    
    Removes:
    - Date lines like "NYS ASSEMBLY                     JUNE 11, 2025"
    - Standalone page numbers
    - Excessive whitespace
    - Leading/trailing newlines
    
    """
    # Remove the NYS ASSEMBLY date line pattern
    # Pattern: "NYS ASSEMBLY" followed by spaces and date
    text = re.sub(
        r'\n?NYS ASSEMBLY\s+[A-Z]+\s+\d{1,2},\s+\d{4}\s*\n?',
        '\n',
        text
    )
    
    # Remove standalone page numbers (just digits on their own line)
    text = re.sub(r'\n\d{1,4}\n', '\n', text)
    
    # Remove page numbers at start of lines (like "2to dispense")
    text = re.sub(r'\n\d{1,3}([a-z])', r'\n\1', text)
    
    # Clean up multiple newlines to max 2
    text = re.sub(r'\n{3,}', '\n\n', text)
    
    # Clean up multiple spaces
    text = re.sub(r' {2,}', ' ', text)
    
    # Strip leading/trailing whitespace
    text = text.strip()
    
    return text

def extract_bill_context(text: str) -> dict:
        """Extract current bill context from text"""
        context = {}
        
        # Extract bill number
        bill_match = PATTERNS['bill_number'].search(text)
        if bill_match:
            context['bill_number'] = bill_match.group(1)
        
        # Extract calendar number
        cal_match = PATTERNS['calendar_number'].search(text)
        if cal_match:
            context['calendar_number'] = cal_match.group(1)
        
        # Extract rules report
        rules_match = PATTERNS['rules_report'].search(text)
        if rules_match:
            context['rules_report_number'] = rules_match.group(1)
        
        return context
    
    
def extract_interactions(
    speaker_data: list[dict[str, str]],
    all_member_names: list[str] = None
) -> list[dict]:
    """
    Extract member to member interactions from speaker data.
    
    Detects:
    - Question/yield patterns ("Will X yield?")
    - Direct addressing ("Mr./Mrs./Ms. NAME")
    - Response patterns (consecutive speakers)
    
    Returns:
        List of interaction dictionaries with format:
            {
                'from_member': 'MR. WALSH',
                'to_member': 'MS. ROZIC',
                'interaction_type': 'question',
                'text_snippet': 'Will the sponsor yield?',
                'position': 42  # Index in speaker_data
            },
    """
    interactions = []
    
    # Extract all member names if not provided
    if all_member_names is None:
        all_member_names = []
        for entry in speaker_data:
            for speaker_key in entry.keys():
                # Normalize to "TITLE NAME" format
                normalized = speaker_key.upper().strip()
                if normalized not in all_member_names:
                    all_member_names.append(normalized)
    
    
    # Create lookup for member names (for faster matching)
    member_name_set = set(name.upper() for name in all_member_names)
    
    # Process each speaker entry
    for idx, entry in enumerate(speaker_data):
        # Get speaker name and text
        speaker = list(entry.keys())[0]
        speech_text = entry[speaker]
        
        # Normalize the speaker key
        from_member = speaker.upper().strip()
        
        # Skip if not a member (e.g., ACTING SPEAKER, THE CLERK)
        if 'ACTING SPEAKER' in from_member or 'CLERK' in from_member:
            continue
        
        # Check for yield/question pattern
        yield_match = PATTERNS['yield_question'].search(speech_text)
        if yield_match:
            # If named member, construct normalized name
            if yield_match.group(1):
                last_name = yield_match.group(1).upper()
                # Find the matching full normalized name
                to_member = _find_matching_member(last_name, member_name_set)
            # If "the sponsor", try to find from context
            else:
                to_member = _find_sponsor_from_context(speaker_data, idx)
            
            if to_member and to_member != from_member:
                interactions.append({
                    'from_member': from_member,
                    'to_member': to_member,
                    'interaction_type': 'question',
                    'text_snippet': yield_match.group(0),
                    'position': idx
                })
        
        # Check for direct address
        address_matches = PATTERNS['direct_address'].finditer(speech_text)
        
        for match in address_matches:
            # Normalize the full address (e.g., "Ms. Rozic" -> "MS. ROZIC")
            addressed_name = match.group(1).upper().strip()
            addressed_name = re.sub(r'\s+', ' ', addressed_name)  # Normalize spaces
            
            # Only include if it's a known member and not self
            if addressed_name in member_name_set and addressed_name != from_member:
                # Avoid duplicates from yield pattern
                if not any(
                    i['from_member'] == from_member and 
                    i['to_member'] == addressed_name and 
                    i['position'] == idx 
                    for i in interactions
                ):
                    interactions.append({
                        'from_member': from_member,
                        'to_member': addressed_name,
                        'interaction_type': 'address',
                        'text_snippet': match.group(0),
                        'position': idx
                    })
                break  # Only record first address per speech
        
        # Check for thank you response
        thank_match = PATTERNS['thank_response'].search(speech_text)
        if thank_match:
            addressed_name = thank_match.group(1).upper().strip()
            addressed_name = re.sub(r'\s+', ' ', addressed_name)
            
            if addressed_name in member_name_set and addressed_name != from_member:
                # Don't duplicate if already recorded
                if not any(
                    i['from_member'] == from_member and 
                    i['to_member'] == addressed_name and 
                    i['position'] == idx 
                    for i in interactions
                ):
                    interactions.append({
                        'from_member': from_member,
                        'to_member': addressed_name,
                        'interaction_type': 'response',
                        'text_snippet': thank_match.group(0),
                        'position': idx
                    })
    
    return interactions


def _find_matching_member(last_name: str, member_name_set: set) -> str:
    
    last_name_upper = last_name.upper()
    for full_name in member_name_set:
        # Check if this full name ends with the last name
        if full_name.endswith(last_name_upper):
            return full_name
    return None


def _find_sponsor_from_context(speaker_data: list[dict[str, str]], current_idx: int) -> str:
    '''
    
    '''
    # Look back up to 5 entries
    for i in range(current_idx - 1, max(0, current_idx - 6), -1):
        entry = speaker_data[i]
        speaker = list(entry.keys())[0]
        normalized_key = speaker.upper().strip()
        
        # Skip acting speaker entries
        if 'ACTING SPEAKER' in normalized_key or 'CLERK' in normalized_key:
            continue
        
        # Return the normalized name
        return normalized_key
    
    return None

# %%
# extract all participation chunks
for match in PATTERNS['speaker'].finditer(full_text):
    title, name, content = match.groups()

    # Skip clerk entries
    if title.startswith("THE CLERK"):
        continue

    # Find line numbers
    match_start = match.start()
    match_end = match.end()

    # Count lines up to this match
    text_before = full_text[:match_start]
    line_start = text_before.count('\n') + 1

    text_in_match = full_text[match_start:match_end]
    line_end = line_start + text_in_match.count('\n')

    # Extract bill context from surrounding text
    context_text = full_text[max(0, match_start - 500):match_end]
    bill_context = extract_bill_context(context_text)

    # Update persistent context
    #current_bill_context.update(bill_context)

    # Determine participation type
    normalized_name = f"{title} {name}"
